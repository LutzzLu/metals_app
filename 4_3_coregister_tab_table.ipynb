# %%
import dash
# import dash_auth
# from users import USERNAME_PASSWORD_PAIRS
from dash import dcc
from dash import html
import plotly
import dash_bootstrap_components as dbc
# import dash_daq as dq
from jupyter_dash import JupyterDash
from dash import Dash
import pandas as pd  
import joblib
import base64, io, os
from dash import  dash_table
import dash
import pandas as pd
from dash import dash_table
import pickle
from dash.dependencies import Input, Output, State, ALL, MATCH
import json
# from functools import reduce
from dash import Input, Output, State, html
from tqdm.notebook import trange, tqdm
import pickle
import numpy as np
import pandas as pd
# from cryptography.fernet import Fernet
import json
import io, base64, os
import pandas as pd
import datetime
import time
import re
import plotly.express as px
import plotly.graph_objects as go
from dash_canvas.utils import array_to_data_url

import geopandas
import tifffile as tiff
import cv2
import matplotlib; matplotlib.rcParams['figure.dpi']=300
import matplotlib.pyplot as plt
import pickle
import numpy as np
from pathpretrain.utils import generate_tissue_mask
import scipy.ndimage as ndimage
from skimage.util import compare_images
from skimage.measure import regionprops_table
from skimage import exposure
import tempfile
import matplotlib.image as mpimg
from skimage import data, draw
from io import BytesIO
import copy
from matplotlib.colors import Normalize as Colors_Normalize
# from scipy import ndimage

# %%
with open("./data/match_dict.pkl", "rb") as file:
    match_dict = pickle.load(file)

annotation_data = geopandas.read_file("./data/_SS12251_140745.geojson")
im_large = tiff.imread("./data/_SS12251_140745.svs")
im_medium = cv2.resize(im_large, None, fx=1/7, fy=1/7)
im_small = cv2.resize(im_large, None, fx=1/15, fy=1/15)

with open("./data/011320_002_N_HR_dict.pkl", "rb") as input_file:
    metal_data = pickle.load(input_file)

# %%
def crop_slide(image_array):
#     slide_file = list(filter(lambda x: match_dict[x] == imageId, match_dict))[0]    
    im_large=image_array#tifffile.imread(f"/dartfs/rc/nosnapshots/V/VaickusL-nb/EDIT_Students/projects/metals/breast/new_slide_images_4_6_23/{slide_file}.svs")

    tissue_mask=generate_tissue_mask(im_large*5,compression=32.,threshold=240,kernel=10,gray_before_close=True) 
    compression=32
    
    # Metal image is only portion of slide
#     if (imageId == "092619_007_T_HER2"):    
        
#     if (imageId == "102720_003_T_TNBC"):
#         labels_small=ndimage.label(cv2.resize(tissue_mask.astype(np.uint8),None,fx=1/compression,fy=1/compression,interpolation=cv2.INTER_NEAREST))[0]
#         lbl_table=pd.DataFrame(regionprops_table(labels_small,properties=['bbox','area',"label"])).sort_values("area",ascending=False)
#         xmin,ymin,xmax,ymax=(lbl_table.iloc[1][[col for col in lbl_table if "bbox" in col]]*compression).astype(int)   
#     else:  
    labels_small=ndimage.label(cv2.resize(tissue_mask.astype(np.uint8),None,fx=1/compression,fy=1/compression,interpolation=cv2.INTER_NEAREST))[0]
    lbl_table=pd.DataFrame(regionprops_table(labels_small,properties=['bbox','area',"label"])).sort_values("area",ascending=False)
    xmin,ymin,xmax,ymax=(lbl_table.iloc[0][[col for col in lbl_table if "bbox" in col]]*compression).astype(int)   
    
    im_large_crop=im_large[xmin:xmax,ymin:ymax].copy()
    im_large_crop[~tissue_mask[xmin:xmax,ymin:ymax]]=255
    
    return im_large_crop, [[xmin, ymin], [xmax, ymax]], tissue_mask

# %%
im_large_crop, minmax_list, tissue_mask = crop_slide(im_large)


im_small_crop = cv2.resize(im_large_crop, None, fx=1/15, fy=1/15)
compression_annotation_tab = metal_data['metals']['Ca44'].shape[0]/im_large_crop.shape[0]
im_small_crop_annotation_tab = cv2.resize(im_large_crop, None, fx=compression_annotation_tab, fy=compression_annotation_tab)

hne_image = px.imshow(im_small_crop)
metal_image = px.imshow(np.log(metal_data['metals']['Ca44'])+10, color_continuous_scale='jet')
# Out:
# /Users/luyunrui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/luyunrui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning:
#
# invalid value encountered in log

# %%
annotation_data['annot']=annotation_data['classification'].map(lambda x: x.get("name","none"))

gp2=annotation_data.copy()
gp2['geometry']=gp2['geometry'].scale(1/7,1/7,origin=(0,0))
gp2['coords'] = gp2['geometry'].apply(lambda x: x.representative_point().coords[:])
gp2['coords'] = [coords[0] for coords in gp2['coords']]

# %%
app = JupyterDash(__name__, 
                  external_stylesheets=[dbc.themes.SPACELAB], 
                 )

markdown_text_title = '''
# **Metals Demo**
'''

all_color_list = px.colors.qualitative.Dark24
result_df = pd.DataFrame({'type': [], 'metal': [], 
                              'mean': [], 'std': []})
newest_result_df = pd.DataFrame({'type': [], 'metal': [], 
                              'mean': [], 'std': []})

all_relayout_data = {'shapes': [], 'dragmode': ''}

type_to_color_dict = {'immune': all_color_list[0], 'tumor': all_color_list[1]}
color_to_type_dict = {all_color_list[0]: 'immune', all_color_list[1]: 'tumor'}

tab_Data_content = dbc.Card(
    dbc.CardBody(
        [
            html.P("This is Data tab", className="card-text"),
        ]
    ),
    className="mt-3",
)

image_no_axis_layout = go.Layout(
    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
)

hne_image.update_layout(image_no_axis_layout)
metal_image.update_layout(image_no_axis_layout)
hne_image.update_layout(title=dict(text="H&E Image", x=0.5, y=0.95, xanchor='center'))

def path_to_indices(path, scale_factor):
    """From SVG path to numpy array of coordinates, each row being a (row, col) point
    """
    indices_str = [
        el.replace("M", "").replace("Z", "").split(",") for el in path.split("L")
    ]
    return np.rint(np.array(indices_str, dtype=float)*(1/scale_factor)).astype(np.int)

def path_to_mask(path, shape, scale_factor, padded_rows, padded_columns):
    path_work = path_to_indices(path, scale_factor)
    path_work[:, 0][path_work[:, 0] == padded_columns] = (padded_columns-1)
    path_work[:, 1][path_work[:, 1] == padded_rows] = (padded_rows-1)
    cols, rows = path_work.T
    rr, cc = draw.polygon(rows, cols)
    mask = np.zeros(shape, dtype=np.bool)
    mask[rr, cc] = True
    mask = ndimage.binary_fill_holes(mask)
    return mask

def update_metal_image(selected_metal, 
                       np_log, 
                      ):
    if np_log == 'With np log transform':
        original_metal_image = metal_data['metals'][selected_metal]
        cmap_jet = plt.cm.get_cmap('jet')
        original_metal_image[original_metal_image <= 0] = 0.000001
        original_metal_image = np.nan_to_num(original_metal_image, nan=0.000001)
        original_metal_image = np.log(original_metal_image)+10
        original_metal_image_normalized = (original_metal_image - original_metal_image.min()) / (original_metal_image.max() - original_metal_image.min())
        metal_image_data = cmap_jet(original_metal_image_normalized)
        metal_image_data = metal_image_data[:, :, :3]
        metal_image = px.imshow(metal_image_data)
    else:
        metal_image_data = metal_data['metals'][selected_metal]
        metal_image = px.imshow(metal_image_data, color_continuous_scale='jet')
        metal_image.layout.coloraxis.showscale = False
    metal_image.update_layout(image_no_axis_layout)
    metal_image.update_layout(title=dict(text="Metal Image - {}".format(selected_metal), x=0.5, y=0.95, xanchor='center'))
    return metal_image

tab_Visualization_content = dbc.Card(
    dbc.CardBody(
        [
            dbc.Row(
            [
                dbc.Col(dcc.Graph(id="hne_image", figure=hne_image,), 
                        width=6),
                dbc.Col(dcc.Graph(id="metal_image", figure=metal_image,),
                        width=6),
            ]
        ),
            dbc.Row([
                dcc.Dropdown(
                            id='metal_dropdown',
                            options=list(metal_data['metals'].keys()),
                            value='Ca44',
                            searchable=True, 
                            style={'width': '110px'},
                                ),
                dcc.Dropdown(
                            id='np_log_dropdown',
                            options=['With np log transform', 'Without np log transform'],
                            value='With np log transform',
                            style={'width': '300px'},
                                ),
            ], justify="end",),
        ]
    ),
    className="mt-3",
)

padded_rows = 1000
padded_columns = 1600

rows_padding = max(0, padded_rows - im_small_crop_annotation_tab.shape[0])
columns_padding = max(0, padded_columns - im_small_crop_annotation_tab.shape[1])
top_pad = rows_padding // 2
bottom_pad = rows_padding - top_pad
left_pad = columns_padding // 2
right_pad = columns_padding - left_pad
im_small_crop_annotation_tab = np.pad(
    im_small_crop_annotation_tab,
    ((top_pad, bottom_pad), (left_pad, right_pad), (0, 0)),
    mode='constant',
    constant_values=255,
)

def output_blank_hne(im_small_crop_annotation_tab):
    blank_figure_hne = go.Figure()

    blank_img_hne_width = im_small_crop_annotation_tab.shape[1]
    blank_img_hne_height = im_small_crop_annotation_tab.shape[0]
    scale_factor = 0.3

    blank_figure_hne.add_trace(
        go.Scatter(
            x=[0, blank_img_hne_width * scale_factor],
            y=[0, blank_img_hne_height * scale_factor],
            mode="markers",
            marker_opacity=0
        )
    )
    blank_figure_hne.update_xaxes(
        visible=False,
        range=[0, blank_img_hne_width * scale_factor]
    )
    blank_figure_hne.update_yaxes(
        visible=False,
        range=[0, blank_img_hne_height * scale_factor],
        scaleanchor="x",
    )
    blank_figure_hne.add_layout_image(
        dict(
            x=0,
            sizex=blank_img_hne_width * scale_factor,
            y=blank_img_hne_height * scale_factor,
            sizey=blank_img_hne_height * scale_factor,
            xref="x",
            yref="y",
            opacity=1.0,
            layer="below",
            sizing="stretch",
            source=array_to_data_url(im_small_crop_annotation_tab))
    )
    blank_figure_hne.update_layout(
        width=blank_img_hne_width * scale_factor,
        height=blank_img_hne_height * scale_factor,
        margin={"l": 0, "r": 0, "t": 0, "b": 0},
        title=dict(text="H&E Image", x=0.5, y=0.95, xanchor='center'),
    )
    return blank_figure_hne
blank_figure_hne = output_blank_hne(im_small_crop_annotation_tab)

padded_rows = 1000
padded_columns = 1600

original_metal_image = metal_data['metals']['Ca44']
rows_padding = max(0, padded_rows - original_metal_image.shape[0])
columns_padding = max(0, padded_columns - original_metal_image.shape[1])
top_pad = rows_padding // 2
bottom_pad = rows_padding - top_pad
left_pad = columns_padding // 2
right_pad = columns_padding - left_pad
padded_metal_image = np.pad(original_metal_image, ((top_pad, bottom_pad), (left_pad, right_pad)), mode='constant')

cmap_jet = plt.cm.get_cmap('jet')
padded_metal_image[padded_metal_image <= 0] = 0.000001
padded_metal_image = np.nan_to_num(padded_metal_image, nan=0.000001)
padded_metal_image = np.log(padded_metal_image)+10
padded_metal_image_normalized = (padded_metal_image - padded_metal_image.min()) / (padded_metal_image.max() - padded_metal_image.min())
padded_metal_image_rgb = cmap_jet(padded_metal_image_normalized)
padded_metal_image_rgb = padded_metal_image_rgb[:, :, :3]

blank_figure = go.Figure()

blank_img_width = padded_columns
blank_img_height = padded_rows
scale_factor = 0.35

blank_figure.add_trace(
    go.Scatter(
        x=[0, blank_img_width * scale_factor],
        y=[0, blank_img_height * scale_factor],
        mode="markers",
        marker_opacity=0
    )
)

blank_figure.update_xaxes(
    visible=False,
    range=[0, blank_img_width * scale_factor]
)

blank_figure.update_yaxes(
    visible=False,
    range=[0, blank_img_height * scale_factor],
    scaleanchor="x",
)
    
blank_figure.add_layout_image(
    dict(
        x=0,
        sizex=blank_img_width * scale_factor,
        y=blank_img_height * scale_factor,
        sizey=blank_img_height * scale_factor,
        xref="x",
        yref="y",
        opacity=1.0,
        layer="below",
        sizing="stretch",
        source=array_to_data_url((padded_metal_image_rgb * 255).astype(np.uint8)),)
)

blank_figure.update_layout(
    width=blank_img_width * scale_factor,
    height=blank_img_height * scale_factor,
    margin={"l": 0, "r": 0, "t": 0, "b": 0},
)

image_annotation_card = dbc.Card(
    children = [dbc.CardHeader(html.H2("Annotation area")),
        dbc.CardBody(
            [
                dcc.Graph(
                    id="annotate_metal_image",
                    figure=blank_figure,
                    config={"modeBarButtonsToAdd": ["drawrect", "eraseshape", "drawclosedpath",], 
                            'modeBarButtonsToRemove': [
                                                        'zoom2d', 
                                                       'pan2d', 
                                                       'zoomIn2d', 'zoomOut2d', 
                                                        ]},
                ),
                dcc.Store(id='annotation_store', data=[]),
                dbc.Row([
                    html.Div("color map and metals: ", style={'font-weight': 'bold'}),
                ]),
                dbc.Row([
                    dcc.Dropdown(
                                id='annotation_colormap',
                                options=[{'label': 'viridis', 'value': 'viridis'}, 
                                         {'label': 'jet', 'value': 'jet'}, 
                                         {'label': 'plasma', 'value': 'plasma'}],
                                value='jet',
                                style={'width': '150px'}, 
                                    ),
                    dcc.Dropdown(
                                id='metal_dropdown_annotation',
                                options=list(metal_data['metals'].keys()),
                                value='Ca44',
                                searchable=True, 
                                style={'width': '110px'},
                                    ),
                ], justify="start",),
                dbc.Row([
                    html.Div("vmin and vmax: ", style={'font-weight': 'bold'}),
                    dcc.RangeSlider(-20, 20, value=[0, 1], id="vmin_vmax_input",
                                    marks={
                                        -20: {'label': '-100', 'style': {'color': '#f50'}},
                                        0: {'label': '0', 'style': {'color': '#77b0b1'}},
                                        1: {'label': '1', 'style': {'color': '#77b0b1'}},
                                        20: {'label': '100', 'style': {'color': '#f50'}},
                                    },
                                    pushable=1,
                                    included=False,
                               tooltip={"placement": "bottom", "always_visible": True},
                                ),
                    ], justify="start",),
            ]
        ),
        dbc.CardFooter(
            [
                dcc.Markdown(
                    "To annotate the above image"
                    "rectangle .\n\n"
                    "**Choose metals**:"
                ),
                dbc.Row([
                    dbc.Input(id="type_input", placeholder="Add new type", 
                              type="text", 
                              style={'width': '170px'}, 
                             ),
                    dbc.Button("Add Type", id="add_type_button",
                           size="sm", 
                               n_clicks=0, 
                               style={'width': '100px'}, 
                               className="me-1", 
                              ),
                    dcc.Dropdown(
                                id='type_dropdown_annotation',
                                options=[{'label': 'immune', 'value': 'immune'}, 
                                         {'label': 'tumor', 'value': 'tumor'}],
                                value='immune',
                                style={'width': '150px'}, 
                                    ),
                ], justify="center",),
            ]
        ),]
)

annotation_result_table = dbc.Table.from_dataframe(result_df, striped=True, bordered=True, hover=True)

annotated_data_card = dbc.Card(
    children = [dbc.CardHeader(html.H2("Table")),
        dbc.CardBody(
            [
                html.Div(id='table_container', children = annotation_result_table),
            ]
        ),
        dbc.CardFooter(
            [
                dbc.Button('Calculate Result', id='update_table_button', 
                           size="sm", n_clicks=0, className="me-1"), 
                dbc.Button("Download Table", id="export_data",
                           size="sm", n_clicks=0, className="me-1"),
                dcc.Download(id="download_dataframe_csv"),
            ]
        ),]
)

default_type_color_match_list = []
default_color_to_type_dict = {'#2E91E5': 'immune', '#E15F99': 'tumor'}
for one_color in list(default_color_to_type_dict.keys()):
    new_line = html.P(
        [
            str(default_color_to_type_dict[one_color]),': ',
            html.Span("", style={"background-color": one_color, "width": "15px", "height": "15px", "display": "inline-block", "vertical-align": "middle"}),
            f" {one_color}."
        ],
        style={"display": "flex", "align-items": "center"}
    )
    default_type_color_match_list.append(new_line)

image_annotation_table = dbc.Row(
                                [
                                dbc.Col(
                                    html.Div(children = [
                                    dbc.Row([
                                    dcc.Graph(id="blank_hne_image", figure=blank_figure_hne),
                                        ], justify="center",),
                                    dbc.Row([
                                        html.Div(id="type_color_match_list", children=default_type_color_match_list),
                                        ], justify="center",),]),
                                        width=4),
                                dbc.Col(image_annotation_card, width=5),
                                dbc.Col(annotated_data_card, md=3),
                                ], 
                                justify="start",)

tab_Measure_content = dbc.Card(
    dbc.CardBody(
        [
            image_annotation_table,
        ]
    ),
    className="mt-3",)

































all_coregister_content = html.Div(children = [
                                dbc.Row([
                                    dbc.Col(image_annotation_card, width=5),
                                    dbc.Col(image_annotation_card, width=5),
#                                 dcc.Graph(id="blank_hne_image", figure=blank_figure_hne),
#                                     ], justify="center",),
#                                 dbc.Row([
#                                     html.Div(id="type_color_match_list", 
#                                              children=default_type_color_match_list),
                                    ], justify="between",),]),



tab_Coregister_content = dbc.Card(
    dbc.CardBody(
        [
            all_coregister_content,
        ]
    ),
    className="mt-3",)


all_tabs = dbc.Tabs(
    [
        dbc.Tab(tab_Data_content, label="Data"),
        dbc.Tab(tab_Coregister_content, label="Co-register"),
        dbc.Tab(tab_Measure_content, label="Measure"),
    ]
)

app.layout = html.Div([dcc.Markdown(children=markdown_text_title),
                       all_tabs])

@app.callback(
    Output('metal_image', 'figure'),
    [Input('metal_dropdown', 'value'), 
     Input('np_log_dropdown', 'value')]
)

def update_metal_image_callback(selected_metal, np_log):
    return update_metal_image(selected_metal, np_log)

@app.callback(
    Output('type_dropdown_annotation', 'options'),
    Output('type_color_match_list', 'children'),
    Input('add_type_button', 'n_clicks'),
    State('type_input', 'value'), 
    State('type_dropdown_annotation', 'options')
)

def add_annotation_type(n_clicks, type_input, previous_types):
    if n_clicks > 0 and type_input:
        new_option = {'label': type_input, 'value': type_input}
        if new_option not in previous_types:
            previous_types.append(new_option)
            global type_to_color_dict
            global color_to_type_dict
            already_types_num = len(list(type_to_color_dict.keys()))
            type_to_color_dict[str(type_input)] = all_color_list[already_types_num]
            color_to_type_dict[all_color_list[already_types_num]] = str(type_input)
            
            color_type_match_list = []
            for one_color in list(color_to_type_dict.keys()):
                new_line = html.P(
                    [
                        str(color_to_type_dict[one_color]),': ',
                        html.Span("", style={"background-color": one_color, "width": "15px", "height": "15px", "display": "inline-block", "vertical-align": "middle"}),
                        f" {one_color}."
                    ],
                    style={"display": "flex", "align-items": "center"}
                )
                color_type_match_list.append(new_line)
    return previous_types, color_type_match_list


@app.callback(
    Output('annotate_metal_image', 'figure'),
    Output('blank_hne_image', 'figure'),
    Input('metal_dropdown_annotation', 'value'),
    Input('annotate_metal_image', 'relayoutData'),
    Input('type_dropdown_annotation', 'value'),
    Input('annotation_colormap', 'value'),
    Input('vmin_vmax_input', 'value'), 
)

def update_annotation_callback(selected_metal, 
                               relayout_data,
                               annotation_type,
                               colormap,
                               vmin_vmax,
                              ):
    vmin, vmax = vmin_vmax[0], vmin_vmax[1]
    padded_rows = 1000
    padded_columns = 1600

    original_metal_image = metal_data['metals'][selected_metal]
    rows_padding = max(0, padded_rows - original_metal_image.shape[0])
    columns_padding = max(0, padded_columns - original_metal_image.shape[1])
    top_pad = rows_padding // 2
    bottom_pad = rows_padding - top_pad
    left_pad = columns_padding // 2
    right_pad = columns_padding - left_pad
    padded_metal_image = np.pad(original_metal_image, ((top_pad, bottom_pad), (left_pad, right_pad)), mode='constant')
    padded_metal_image[padded_metal_image <= 0] = 0.000001
    padded_metal_image = np.nan_to_num(padded_metal_image, nan=0.000001)
    padded_metal_image = np.log(padded_metal_image)+10
    
    if vmin and vmax:
        c_norm = Colors_Normalize(vmin=vmin, vmax=vmax)
        padded_metal_image_normalized = c_norm(padded_metal_image)
    else:
        padded_metal_image_normalized = (padded_metal_image - padded_metal_image.min()) / (padded_metal_image.max() - padded_metal_image.min())
    cmap_jet = plt.cm.get_cmap(colormap)
    padded_metal_image_rgb = cmap_jet(padded_metal_image_normalized)
    padded_metal_image_rgb = padded_metal_image_rgb[:, :, :3]

    target_color_to_white = padded_metal_image_rgb[0, 0, :]
    replacement_color_to_white = np.array([1, 1, 1])
    mask_to_white = np.all(padded_metal_image_rgb == target_color_to_white, axis=-1)
    padded_metal_image_rgb[mask_to_white] = replacement_color_to_white

    blank_figure = go.Figure()

    blank_img_width = padded_columns
    blank_img_height = padded_rows
    scale_factor = 0.3

    blank_figure.add_trace(
        go.Scatter(
            x=[0, blank_img_width * scale_factor],
            y=[0, blank_img_height * scale_factor],
            mode="markers",
            marker_opacity=0
        )
    )
    blank_figure.update_xaxes(
        visible=False,
        range=[0, blank_img_width * scale_factor]
    )
    blank_figure.update_yaxes(
        visible=False,
        range=[0, blank_img_height * scale_factor],
        scaleanchor="x",
    )
    blank_figure.add_layout_image(
        dict(
            x=0,
            sizex=blank_img_width * scale_factor,
            y=blank_img_height * scale_factor,
            sizey=blank_img_height * scale_factor,
            xref="x",
            yref="y",
            opacity=1.0,
            layer="below",
            sizing="stretch",
            source=array_to_data_url((padded_metal_image_rgb * 255).astype(np.uint8)),)
    )
    blank_figure.update_layout(
        width=blank_img_width * scale_factor,
        height=blank_img_height * scale_factor,
        margin={"l": 0, "r": 0, "t": 0, "b": 0},
    )

    blank_hne_image = output_blank_hne(im_small_crop_annotation_tab)

    if relayout_data:
        if 'shapes' in list(relayout_data.keys()):
            if len(relayout_data['shapes']) > len(all_relayout_data['shapes']):
                append_relayout = relayout_data['shapes'][-1]
                append_relayout['line']['color'] = type_to_color_dict[annotation_type]
                all_relayout_data['shapes'].append(append_relayout)
            elif len(relayout_data['shapes']) < len(all_relayout_data['shapes']):
                all_relayout_data['shapes'] = relayout_data['shapes']
        if 'dragmode' in list(relayout_data.keys()):
            all_relayout_data['dragmode'] = relayout_data['dragmode']
        for one_shape in all_relayout_data['shapes']:
            one_shape['line']['width'] = 2
        blank_figure['layout'].update(all_relayout_data)
        blank_hne_image['layout'].update(all_relayout_data)
    return blank_figure, blank_hne_image

@app.callback(
    Output('table_container', 'children'),
    Input('annotate_metal_image', 'relayoutData'),
    Input('update_table_button', 'n_clicks'),
    State('table_container', 'children'),
)

def update_table_callback(relayout_data, n_clicks, table_children):
    if n_clicks is None:
        return table_children
    
    if n_clicks == 0:
        return table_children

    padded_rows = 1000
    padded_columns = 1600
    scale_factor = 0.35
    
    all_type_list = []
    for one_shape in all_relayout_data['shapes']:
        all_type_list.append(color_to_type_dict[one_shape['line']['color']])
    all_type_list = list(set(all_type_list))
    
    all_type_area_list_dict = {}
    for one_type in all_type_list:
        all_type_area_list_dict[one_type] = []
    
    for one_shape in all_relayout_data['shapes']:
        all_type_area_list_dict[color_to_type_dict[one_shape['line']['color']]].append(one_shape['path'])
        
    all_type_area_dict = {}
        
    for one_type in list(all_type_area_list_dict.keys()):
        for one_path in all_type_area_list_dict[one_type]:
            if one_type not in list(all_type_area_dict.keys()):
                all_type_area_dict[one_type] = path_to_mask(one_path, (padded_rows, padded_columns), 
                                                            scale_factor, 
                                                            padded_rows, padded_columns)
            else:
                all_type_area_dict[one_type] += path_to_mask(one_path, (padded_rows, padded_columns), 
                                                            scale_factor, 
                                                            padded_rows, padded_columns)
    
    type_df_list = []
    metal_df_list = []
    mean_df_list = []
    std_df_list = []
    
    for one_type in list(all_type_area_dict.keys()):
        one_area = all_type_area_dict[one_type]
        for one_metal in list(metal_data['metals'].keys()):
            original_metal_image = metal_data['metals'][one_metal]
            rows_padding = max(0, padded_rows - original_metal_image.shape[0])
            columns_padding = max(0, padded_columns - original_metal_image.shape[1])
            top_pad = rows_padding // 2
            bottom_pad = rows_padding - top_pad
            left_pad = columns_padding // 2
            right_pad = columns_padding - left_pad
            padded_metal_image = np.pad(original_metal_image, 
                                        ((top_pad, bottom_pad), 
                                         (left_pad, right_pad)), 
                                        mode='constant')
            padded_metal_image = np.nan_to_num(padded_metal_image, nan=0.000001)
            
            type_df_list.append(one_type)
            metal_df_list.append(one_metal)
            mean_df_list.append(round(padded_metal_image[one_area].mean(), 3))
            std_df_list.append(round(padded_metal_image[one_area].std(), 3))
            
    result_df = pd.DataFrame({'type': type_df_list, 'metal': metal_df_list, 
                              'mean': mean_df_list, 'std': std_df_list})
    
    newest_result_df = pd.DataFrame({'type': type_df_list, 'metal': metal_df_list, 
                              'mean': mean_df_list, 'std': std_df_list})
    annotation_result_table = dbc.Table.from_dataframe(result_df, striped=True, bordered=True, hover=True)
    
    return annotation_result_table

@app.callback(
    Output("download_dataframe_csv", "data"),
    Input("export_data", "n_clicks"),
    State('table_container', 'children'),
    prevent_initial_call=True,
)

def export_on_click(n_clicks, table_children):
    return dcc.send_data_frame(newest_result_df.to_csv, "export_result.csv")

# %%
app.run_server(debug=False,
               mode="external",
               host='localhost',
              )
# Out:
#  * Running on http://localhost:8050 (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Aug/2023 15:59:33] "GET /_alive_df887191-9313-43af-8907-1479d9e20685 HTTP/1.1" 200 -
# Dash app running on http://localhost:8050/

# %%
xy_index = []

co_hne_x_list = []
co_hne_y_list = []

fig_hne_co = px.imshow(im_small_crop)
fig_hne_co.add_scatter(
    x=[],
    y=[],
    mode='markers',
    marker_color='black',
    marker_size=5,
)
fig_hne_co.update_layout(
    template='plotly_dark',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
    width=700,#700,
    height=500,#500,
    margin={
        'l': 0,
        'r': 0,
        't': 0,
        'b': 0,
    }
)
fig_hne_co.update_xaxes(visible=False,)
fig_hne_co.update_yaxes(visible=False,)
fig_hne_co.update_coloraxes(showscale=False)



co_metal_x_list = []
co_metal_y_list = []

padded_rows_co = 1000
padded_columns_co = 1600
original_metal_image_co = metal_data['metals']['Ca44']
rows_padding_co = max(0, padded_rows_co - original_metal_image_co.shape[0])
columns_padding_co = max(0, padded_columns_co - original_metal_image_co.shape[1])
top_pad_co = rows_padding_co // 2
bottom_pad_co = rows_padding_co - top_pad_co
left_pad_co = columns_padding_co // 2
right_pad_co = columns_padding_co - left_pad_co
padded_metal_image_co = np.pad(original_metal_image_co, ((top_pad_co, bottom_pad_co), (left_pad_co, right_pad_co)), mode='constant')
cmap_jet = plt.cm.get_cmap('jet')
padded_metal_image_co[padded_metal_image_co <= 0] = 0.000001
padded_metal_image_co = np.nan_to_num(padded_metal_image_co, nan=0.000001)
padded_metal_image_co = np.log(padded_metal_image_co)+10
padded_metal_image_normalized_co = (padded_metal_image_co - padded_metal_image_co.min()) / (padded_metal_image_co.max() - padded_metal_image_co.min())
padded_metal_image_rgb_co = cmap_jet(padded_metal_image_normalized_co)
padded_metal_image_rgb_co = padded_metal_image_rgb_co[:, :, :3]
target_color_to_white_co = padded_metal_image_rgb_co[0, 0, :]
replacement_color_to_white_co = np.array([1, 1, 1])
mask_to_white_co = np.all(padded_metal_image_rgb_co == target_color_to_white_co, axis=-1)
padded_metal_image_rgb_co[mask_to_white_co] = replacement_color_to_white_co

fig_metal_co = px.imshow(padded_metal_image_rgb_co)
fig_metal_co.add_scatter(
    x=[],
    y=[],
    mode='markers',
    marker_color='black',
    marker_size=5,
)
fig_metal_co.update_layout(
    template='plotly_dark',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
    width=700,#700,
    height=500,#500,
    margin={
        'l': 0,
        'r': 0,
        't': 0,
        'b': 0,
    }
)
fig_metal_co.update_xaxes(visible=False,)
fig_metal_co.update_yaxes(visible=False,)
fig_metal_co.update_coloraxes(showscale=False)


original_df_co = pd.DataFrame({'index': xy_index, 
                               'hne x': co_hne_x_list, 'hne y': co_hne_y_list, 
                            'metals x': co_metal_x_list, 'metals y': co_metal_y_list, })


app = JupyterDash(__name__, 
                  external_stylesheets=[dbc.themes.SPACELAB], 
                 )

xy_coords_table = dash_table.DataTable(
        id='datatable-interactivity',
        columns=[
            {"name": i, "id": i,} for i in original_df_co.columns
        ],
        data=original_df_co.to_dict('records'),
        editable=True, row_deletable=True,)

app.layout = dbc.Container(
    [
        dbc.Row(
            [dbc.Col(
                dcc.Graph(
                    id='graph_hne_co',
                    figure=fig_hne_co,
                    config={
                        'displayModeBar': False,
                    }
                ),
                width={'size': 5, 'offset': 0}
            ),
             dbc.Col(
                 html.Div(children = [
                     dcc.Graph(
                    id='graph_metal_co',
                    figure=fig_metal_co,
                    config={'displayModeBar': False,}),
                     dbc.Row(
                     [dcc.Dropdown(
                                id='metal_colormap_co',
                                options=['jet', 'viridis', 'plasma'],
                                value='jet',
                                searchable=True, 
                                style={'width': '110px'},
                                    ),
                    dcc.Dropdown(
                                id='metal_dropdown_co',
                                options=list(metal_data['metals'].keys()),
                                value='Ca44',
                                searchable=True, 
                                style={'width': '110px'},
                                    ),], justify='center')
                     
                 ],
                 ),
                width={'size': 5, 'offset': 0}
            ),
    ], justify='between'
        ),
        dbc.Row(
            [
#             dash_table.DataTable(
#         id='datatable-interactivity',
#         columns=[
#             {"name": i, "id": i,} for i in original_df_co.columns
#         ],
#         data=original_df_co.to_dict('records'),)
                dbc.Col(
                html.Div(id='table_container_co', children = xy_coords_table), width={'size': 6,}),
                dcc.Interval(
                            id='live_update',
                            interval=1*1000, # in milliseconds
                            n_intervals=0,
                        )
#                 dbc.Table.from_dataframe(result_df, striped=True, bordered=True, hover=True)
        ], justify='center'),
    ], fluid=True
)


@app.callback(
    Output('graph_metal_co', 'figure'),
    Input('metal_colormap_co', 'value'),
    Input('metal_dropdown_co', 'value'),
    Input('graph_metal_co', 'clickData'),
)

def update_co_metal_image(metal_colormap_co, metal_dropdown_co, clickData):
    if not clickData:
        padded_rows_co = 1000
        padded_columns_co = 1600
        original_metal_image_co = metal_data['metals'][metal_dropdown_co]
        rows_padding_co = max(0, padded_rows_co - original_metal_image_co.shape[0])
        columns_padding_co = max(0, padded_columns_co - original_metal_image_co.shape[1])
        top_pad_co = rows_padding_co // 2
        bottom_pad_co = rows_padding_co - top_pad_co
        left_pad_co = columns_padding_co // 2
        right_pad_co = columns_padding_co - left_pad_co
        padded_metal_image_co = np.pad(original_metal_image_co, ((top_pad_co, bottom_pad_co), (left_pad_co, right_pad_co)), mode='constant')
        cmap_jet = plt.cm.get_cmap(metal_colormap_co)
        padded_metal_image_co[padded_metal_image_co <= 0] = 0.000001
        padded_metal_image_co = np.nan_to_num(padded_metal_image_co, nan=0.000001)
        padded_metal_image_co = np.log(padded_metal_image_co)+10
        padded_metal_image_normalized_co = (padded_metal_image_co - padded_metal_image_co.min()) / (padded_metal_image_co.max() - padded_metal_image_co.min())
        padded_metal_image_rgb_co = cmap_jet(padded_metal_image_normalized_co)
        padded_metal_image_rgb_co = padded_metal_image_rgb_co[:, :, :3]
        target_color_to_white_co = padded_metal_image_rgb_co[0, 0, :]
        replacement_color_to_white_co = np.array([1, 1, 1])
        mask_to_white_co = np.all(padded_metal_image_rgb_co == target_color_to_white_co, axis=-1)
        padded_metal_image_rgb_co[mask_to_white_co] = replacement_color_to_white_co

        fig_metal_co = px.imshow(padded_metal_image_rgb_co)
        fig_metal_co.add_scatter(
            x=[],
            y=[],
            mode='markers',
            marker_color='black',
            marker_size=5,
        )
        fig_metal_co.update_layout(
            template='plotly_dark',
            plot_bgcolor='rgba(0, 0, 0, 0)',
            paper_bgcolor='rgba(0, 0, 0, 0)',
            width=700,#700,
            height=500,#500,
            margin={
                'l': 0,
                'r': 0,
                't': 0,
                'b': 0,
            }
        )
        fig_metal_co.update_xaxes(visible=False,)
        fig_metal_co.update_yaxes(visible=False,)
        fig_metal_co.update_coloraxes(showscale=False)
        return fig_metal_co
    else:
        padded_rows_co = 1000
        padded_columns_co = 1600
        original_metal_image_co = metal_data['metals'][metal_dropdown_co]
        rows_padding_co = max(0, padded_rows_co - original_metal_image_co.shape[0])
        columns_padding_co = max(0, padded_columns_co - original_metal_image_co.shape[1])
        top_pad_co = rows_padding_co // 2
        bottom_pad_co = rows_padding_co - top_pad_co
        left_pad_co = columns_padding_co // 2
        right_pad_co = columns_padding_co - left_pad_co
        padded_metal_image_co = np.pad(original_metal_image_co, ((top_pad_co, bottom_pad_co), (left_pad_co, right_pad_co)), mode='constant')
        cmap_jet = plt.cm.get_cmap(metal_colormap_co)
        padded_metal_image_co[padded_metal_image_co <= 0] = 0.000001
        padded_metal_image_co = np.nan_to_num(padded_metal_image_co, nan=0.000001)
        padded_metal_image_co = np.log(padded_metal_image_co)+10
        padded_metal_image_normalized_co = (padded_metal_image_co - padded_metal_image_co.min()) / (padded_metal_image_co.max() - padded_metal_image_co.min())
        padded_metal_image_rgb_co = cmap_jet(padded_metal_image_normalized_co)
        padded_metal_image_rgb_co = padded_metal_image_rgb_co[:, :, :3]
        target_color_to_white_co = padded_metal_image_rgb_co[0, 0, :]
        replacement_color_to_white_co = np.array([1, 1, 1])
        mask_to_white_co = np.all(padded_metal_image_rgb_co == target_color_to_white_co, axis=-1)
        padded_metal_image_rgb_co[mask_to_white_co] = replacement_color_to_white_co

        fig_metal_co = px.imshow(padded_metal_image_rgb_co)
        fig_metal_co.add_scatter(
            x=[],
            y=[],
            mode='markers',
            marker_color='black',
            marker_size=5,
        )
        fig_metal_co.update_layout(
            template='plotly_dark',
            plot_bgcolor='rgba(0, 0, 0, 0)',
            paper_bgcolor='rgba(0, 0, 0, 0)',
            width=700,#700,
            height=500,#500,
            margin={
                'l': 0,
                'r': 0,
                't': 0,
                'b': 0,
            }
        )
        fig_metal_co.update_xaxes(visible=False,)
        fig_metal_co.update_yaxes(visible=False,)
        fig_metal_co.update_coloraxes(showscale=False)
        
        global co_metal_x_list
        global co_metal_y_list
        points = clickData.get('points')[0]
        x = points.get('x')
        y = points.get('y')
        
        co_metal_x_list.append(x)
        co_metal_y_list.append(y)
        
        fig_metal_co['data'][1].update(x=co_metal_x_list)
        fig_metal_co['data'][1].update(y=co_metal_y_list)
        
        return fig_metal_co

@app.callback(
    Output('graph_hne_co', 'figure'),
    State('graph_hne_co', 'figure'),
    Input('graph_hne_co', 'clickData')
)
def get_click_hne(graph_figure, clickData):
    if not clickData:
        fig_hne_co = px.imshow(im_small_crop)
        fig_hne_co.add_scatter(
            x=[],
            y=[],
            mode='markers',
            marker_color='black',
            marker_size=5,
        )
        fig_hne_co.update_layout(
            template='plotly_dark',
            plot_bgcolor='rgba(0, 0, 0, 0)',
            paper_bgcolor='rgba(0, 0, 0, 0)',
            width=700,#700,
            height=500,#500,
            margin={
                'l': 0,
                'r': 0,
                't': 0,
                'b': 0,
            }
        )
        fig_hne_co.update_xaxes(visible=False,)
        fig_hne_co.update_yaxes(visible=False,)
        fig_hne_co.update_coloraxes(showscale=False)
        
        return fig_hne_co
    else:
        fig_hne_co = px.imshow(im_small_crop)
        fig_hne_co.add_scatter(
            x=[],
            y=[],
            mode='markers',
            marker_color='black',
            marker_size=5,
        )
        fig_hne_co.update_layout(
            template='plotly_dark',
            plot_bgcolor='rgba(0, 0, 0, 0)',
            paper_bgcolor='rgba(0, 0, 0, 0)',
            width=700,#700,
            height=500,#500,
            margin={
                'l': 0,
                'r': 0,
                't': 0,
                'b': 0,
            }
        )
        fig_hne_co.update_xaxes(visible=False,)
        fig_hne_co.update_yaxes(visible=False,)
        fig_hne_co.update_coloraxes(showscale=False)
        
        points = clickData.get('points')[0]
        x = points.get('x')
        y = points.get('y')
        
        global co_hne_x_list
        global co_hne_y_list
        co_hne_x_list.append(x)
        co_hne_y_list.append(y)

        fig_hne_co['data'][1].update(x=co_hne_x_list)
        fig_hne_co['data'][1].update(y=co_hne_y_list)
        
    return fig_hne_co

@app.callback(
    Output('table_container_co', 'children'),
    Input('live_update', 'n_intervals'),
#     Input('graph_metal_co', 'clickData'),
)
def update_table(n_intervals):
#     print('111')
    if len(co_hne_x_list)>0 or len(co_metal_x_list)>0:
#         print('11')
        update_index = []
        update_hne_x = []
        update_hne_y = []
        update_metal_x = []
        update_metal_y = []
        
        longest_length = max(len(co_hne_x_list), len(co_metal_x_list))
        for i in range(longest_length):
            update_index.append(str(i+1))
            try:
                update_hne_x.append(co_hne_x_list[i])
                update_hne_y.append(co_hne_y_list[i])
            except:
                update_hne_x.append('-')
                update_hne_y.append('-')
            try:
                update_metal_x.append(co_metal_x_list[i])
                update_metal_y.append(co_metal_y_list[i])
            except:
                update_metal_x.append('-')
                update_metal_y.append('-')
            
            update_df = pd.DataFrame({'index': update_index, 
                               'hne x': update_hne_x, 'hne y': update_hne_y, 
                            'metals x': update_metal_x, 'metals y': update_metal_y, })
            xy_coords_table = dash_table.DataTable(
                                            id='datatable-interactivity',
                                            columns=[
                                                {"name": i, "id": i,} for i in update_df.columns
                                            ],
                                            data=update_df.to_dict('records'),
                                            editable=True, row_deletable=True,)
    else:
#         print('1')
        xy_coords_table = dash_table.DataTable(
                                            id='datatable-interactivity',
                                            columns=[
                                                {"name": i, "id": i,} for i in original_df_co.columns
                                            ],
                                            data=original_df_co.to_dict('records'),
                                            editable=True, row_deletable=True,)
    return xy_coords_table


app.run_server(debug=False,
               mode="external",
               host='localhost',
              )
# Out:
#  * Running on http://localhost:8050 (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Aug/2023 10:38:37] "GET /_alive_ef391bb0-a0e5-4461-99c5-75e9fdd8ed15 HTTP/1.1" 200 -
# Dash app running on http://localhost:8050/
# 127.0.0.1 - - [09/Aug/2023 10:38:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET /_favicon.ico?v=2.5.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 304 -
# 127.0.0.1 - - [09/Aug/2023 10:38:38] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 304 -
# 127.0.0.1 - - [09/Aug/2023 10:38:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:38:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:39:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:40:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:41:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:42:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:43:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:44:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:45:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:46:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:47:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Aug/2023 10:48:34] "POST /_dash-update-component HTTP/1.1" 200 -
